# %%
import pandas as pd
import os
import bs4
import requests
import boto3
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


# These are pre-determined for now but can be overwritten
BANKING_CODES = {
    "Barclays": 0,
    "Natwest": 23,
    "Nationwide": 4
}


# Test URL for FOS
BASE_URL = "https://www.financial-ombudsman.org.uk/decisions-case-studies/ombudsman-decisions/search?Keyword=scam&Business={banking_code}&DateFrom=2022-01-01&DateTo=2022-06-01&{upheld_code}&Sort=relevance"

# %%
# You can see that you can use the search within the parameters of the URL
def determine_banking_codes(use_specified: bool = True, additional_key_values: dict = {}):
    """
    Function that can scrap the FOS website for the banking codes and keys
    
    :param use_specified: Bool, use default, pre-specified banking code
    :param additional_key_values: dict, if we use pre-specified code, we can add extra key and values
    :return: dict, key and value of bank and banking code
    """


    if use_specified:
        banking_codes = BANKING_CODES
        if len(additional_key_values) > 0:
            for key, value in additional_key_values:
                banking_codes[key] = value
    else:
        # Need to add a webscraping function tograb from FOS website
        print("Need to implement")


    return banking_codes

# %%
def obtain_number_results(url: str, banking_code: int, is_upheld: bool = True) -> int:
    """
    Function to obtain the number of search results for Upheld/Not Upheld.

    :param url: str, url of FOS webpage
    :param banking_code: int, business code according to FOS
    :param is_upheld: Boolean, determines how to amend the url
    :return: int, number of search results

    """


    upheld_code = "IsUpheld%5B1%5D=1" if is_upheld else "IsUpheld%5B0%5D=0"

    amended_url = url.format(banking_code=str(banking_code), upheld_code=upheld_code)
    
    res = requests.get(amended_url)

    soup = bs4.BeautifulSoup(res.text, "html.parser")

    out = soup.find_all("div", {"class": "search-results-holder"})[0]
    print(out)

    search_results = out.text.split("\n")[1].split()[-2]

    
    return int(search_results)

# %%
def upheld_vs_not_upheld(banking_codes: dict) -> pd.DataFrame:
    """
    Function to grab the upheld vs not upheld cases

    :param banking_codes: dict, codes of the banks
    :return: pd.DataFrame
    """
    
    if len(banking_codes) == 0:
        logger.error("No banking codes")
        raise


    search_results = {}


    for key, value in banking_codes.items():
        logger.info("Bank: %s - Start", key)
        search_results[key] = {}
        search_results[key]["upheld"] = obtain_number_results(url=BASE_URL, banking_code=str(value), is_upheld=True)
        search_results[key]["not_upheld"] = obtain_number_results(url=BASE_URL, banking_code=str(value), is_upheld=False)
        search_results[key]["proportion"] = search_results[key]["upheld"]/(search_results[key]["not_upheld"] + search_results[key]["upheld"])
        logger.info("Bank: %s - End", key)


    df = pd.DataFrame(search_results).T


    return df

# %%
def run():
    """
    Main orchestration function

    :return: number of search results
    """


    print("Determine Banks - NEEDS TO BE UPDATED")    
    banking_codes = determine_banking_codes(
        use_specified=True, 
        additional_key_values={}
        )


    print("Begin FOS scrape")


    df = upheld_vs_not_upheld(banking_codes=banking_codes)

    print("Push to Twitter")
    # Add a step to login into an account and push to twitter
    

    return df

# %%
if __name__ == "__main__":
    output = run()
    print(output)
# Out:
# INFO:__main__:Bank: Barclays - Start
# Determine Banks - NEEDS TO BE UPDATED
# Begin FOS scrape
# <div class="search-results-holder">
# <p>Your search returned 368 results</p>
# <ul class="search-results" role="list">
# <li>
# <a class="search-result" href="decision/DRN-3148865.pdf" target="_blank">
# <h4>Decision Reference DRN-3148865</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>14 Jan 2022</em>
# <span class="search-result__separator"></span>
#                                                             Barclays Bank UK PLC
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-
bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-2475240 The complaint Mrs K is seeking to recover approximately £141,000 from HSBC UK Bank Plc (“HSBC”), which she lost from her account as a result of a third-party scam. HSBC says it is not liable for the loss because Mrs K unwittingly authorised the payment herself – and it could no...
#
#                                                         <strong>
#                                                             (5 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3026109.pdf" target="_blank">
# <h4>Decision Reference DRN-3026109</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>4 Jan 2022</em>
# <span class="search-result__separator"></span>
#                                                             TSB Bank plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3026109 The complaint Mr J complains that TSB Bank Plc didn’t do enough to prevent him becoming the victim of a scam. What happened The detailed background to this complaint is well known to both parties. So, I’ll only provide an overview of some of the key events here. In 2018 Mr J wa...
#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# </ul>
# <div class="pagination-wrap">
# <span class="page-num">
# <strong class="page-num-curr">1</strong> of 62
#     </span>
# <a aria-label="Next page" class="pager-btn pager-next" href="/decisions-case-studies/ombudsman-decisions/search?Keyword=scam&amp;Business=0&amp;DateFrom=2022-01-01&amp;DateTo=2022-06-01&amp;IsUpheld%5B0%5D=0&amp;Sort=relevance&amp;Start=10" title="Next page">Next <i aria-hidden="true" class="icon-chevron-right"></i></a>
# </div>
# </div>
# <div class="search-results-holder">
# <p>Your search returned 5 results</p>
# <ul class="search-results" role="list">
# <li>
# <a class="search-result" href="decision/DRN-3347192.pdf" target="_blank">
# <h4>Decision Reference DRN-3347192</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>23 Mar 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3347192 The complaint and background Mr A complains that National Westminster Bank Plc (“NatWest”) failed to refund money he lost as part of an investment scam. The details of this complaint are well known to both parties, so I will not repeat everything again in detail here. However, ...
#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3392268.pdf" target="_blank">
# <h4>Decision Reference DRN-3392268</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>23 Mar 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3392268 The complaint A limited company which I’ll refer to as ‘B’ complains about the actions of National Westminster Bank Plc as the recipient bank of funds B was tricked into sending as the result of a scam. Mr S, who is a director of B, brings the complaint on B’s behalf. For ease ...
#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3470501.pdf" target="_blank">
# <h4>Decision Reference DRN-3470501</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>27 May 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3470501 The complaint Ms J is unhappy with the service provided by National Westminster Bank Plc after she was the victim of a scam. What happened On 14 January 2022, Ms J was called by someone pretending to be her bank. She was persuaded to make three payments to fraudsters under the ...
#
#                                                         <strong>
#                                                             (2 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3259316.pdf" target="_blank">
# <h4>Decision Reference DRN-3259316</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>19 Jan 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3259316 The complaint Mr and Mrs S complain that National Westminster Bank Plc unreasonably stopped them from buying some shares using their debit card. What happened In November 2020, Mr and Mrs S were given an opportunity to buy some shares in a company. But they had to make the purc...
#
#                                                         <strong>
#                                                             (4 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3481777.pdf" target="_blank">
# <h4>Decision Reference DRN-3481777</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>19 May 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3481777 The complaint Mr S is unhappy National Westminster Bank PLC ( NatWest) declined to process a £300,000 payment until he visited a second branch with a different form of identification. What happened The details of this complaint are well known to both parties, so I won’t repeat ...
#
#                                                         <strong>
#                                                             (2 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# </ul>
# </div>
# INFO:__main__:Bank: Natwest - End
# INFO:__main__:Bank: Nationwide - Start
# <div class="search-results-holder">
# <p>Your search returned 38 results</p>
# <ul class="search-results" role="list">
# <li>
# <a class="search-result" href="decision/DRN-3417596.pdf" target="_blank">
# <h4>Decision Reference DRN-3417596</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>9 May 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3417596 Complaint Ms J is unhappy that National Westminster Bank Plc (“NatWest”) didn’t do more to protect her when she was the victim of a scam. Background In January 2019, Ms J was the victim of an investment scam. She’d been looking for investment opportunities online and found the ...
#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-2736067.pdf" target="_blank">
# <h4>Decision Reference DRN-2736067</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>7 Jan 2022</em>
# <span class="search-result__separator"></span>
#                                                             National Westminster Bank Plc
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-2736067 The complaint Mr P complains that National Westminster Bank Plc didn’t do enough to protect him from falling victim to an investment scam. What happened The detailed background to this complaint is well known to both parties. So, I’ll only provide an overview of some of the key...
#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-

#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3391516.pdf" target="_blank">
# <h4>Decision Reference DRN-3391516</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>23 Mar 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3391516 The complaint Mr B is unhappy that Nationwide Building Society won’t refund him after he lost money to a car purchase scam. Mr B is represented by his friend in bringing this complaint. But for ease of reading, I’ll refer to any submission and comments she has made as being mad...
#
#                                                         <strong>
#                                                             (6 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3321559.pdf" target="_blank">
# <h4>Decision Reference DRN-3321559</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>17 Feb 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3321559 The complaint Mr B complains that Nationwide Building Society has refused to carry out a chargeback for money he lost when he fell victim to as scam. He also believes Nationwide ought to have done more to prevent the transactions from being carried out in the first place. What ...
#
#                                                         <strong>
#                                                             (4 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3211299.pdf" target="_blank">
# <h4>Decision Reference DRN-3211299</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>6 Jan 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3211299 The complaint and what happened Mr R complains that Nationwide Building Society won’t reimburse money he lost when he fell victim to scam. The full details of tis complaint are well known to both parties, so I won’t repeat them here. Instead, I’ll recap the points and focus on ...
#
#                                                         <strong>
#                                                             (2 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3305838.pdf" target="_blank">
# <h4>Decision Reference DRN-3305838</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>3 Mar 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3305838 The complaint Mr N complains that Nationwide Building Society (Nationwide) won’t refund the money he lost when he fell victim to a scam. What happened The details of this complaint are well known to both parties, so I won’t repeat them again here. The facts aren’t in dispute, s...
#
#                                                         <strong>
#                                                             (2 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3401243.pdf" target="_blank">
# <h4>Decision Reference DRN-3401243</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>7 Apr 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3401243 The complaint Ms F complains that Nationwide Building Society will not refund the money she lost after falling victim to a scam. What happened The detailed background to this complaint is well known to both parties, so I’ll provide only an overview of the key facts here. In Jun...
#
#                                                         <strong>
#                                                             (4 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3417750.pdf" target="_blank">
# <h4>Decision Reference DRN-3417750</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>25 Apr 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3417750 The complaint Mr A complains that Nationwide Building Society (Nationwide) won’t refund the money he paid someone for his car to be repaired. What happened What Mr A says Mr A says that his car broke down outside his house during lockdown. Lots of garages were closed and his us...
#
#                                                         <strong>
#                                                             (3 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# <li>
# <a class="search-result" href="decision/DRN-3365761.pdf" target="_blank">
# <h4>Decision Reference DRN-3365761</h4>
# <div class="search-result__info">
# <div class="search-result__info-main">
# <em>30 Mar 2022</em>
# <span class="search-result__separator"></span>
#                                                             Nationwide Building Society
#
#
#                                                         <span class="search-result__separator"></span>
#                                                         Not upheld
#                                                     </div>
# <span class="search-result__tag tag tag--light">Banking and Payments</span>
# </div>
# <div class="search-result__desc">
#                                                     DRN-3365761 The complaint Mr I complains that Nationwide Building Society refuses to refund payments he made to a scam binary options investment company. What happened The facts of the case are well known to both parties so I don’t intend to repeat them in detail here.  Mr I was persuaded ...
#
#                                                         <strong>
#                                                             (2 pages)
#                                                         </strong>
# </div>
# <span class="lnk">View decision</span>
# </a>
# </li>
# </ul>
# <div class="pagination-wrap">
# <span class="page-num">
# <strong class="page-num-curr">1</strong> of 2
#     </span>
# <a aria-label="Next page" class="pager-btn pager-next" href="/decisions-case-studies/ombudsman-decisions/search?Keyword=scam&amp;Business=4&amp;DateFrom=2022-01-01&amp;DateTo=2022-06-01&amp;IsUpheld%5B0%5D=0&amp;Sort=relevance&amp;Start=10" title="Next page">Next <i aria-hidden="true" class="icon-chevron-right"></i></a>
# </div>
# </div>
# Push to Twitter
#             upheld  not_upheld  proportion
# Barclays     368.0       612.0    0.375510
# Natwest        5.0        38.0    0.116279
# Nationwide     8.0        12.0    0.400000
